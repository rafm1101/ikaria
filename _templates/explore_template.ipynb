# %%
# allows update of external libraries without need to reload package
# %load_ext autoreload
# %autoreload 2

# %% [markdown]
# # Fun w/ Templates
#
# ## Summary
#
# Quick and precise summary.
#
# ## Results
#
# ### Key results
#
# .
#
# ### Details
#
# .
#
# ## Structure
#
# 1. Imports and setup.
# 2. Read and preprocess data.
#
# ## Changelog
#
# | version | date | change |
# |---------|------|--------|
# | 1 | 2025-12-15 | initial creation |
# | - |  |  |
#
#
# ## Imports and setup

# %%
import numpy as np

# %% [markdown]
# ## Read and preprocess data
